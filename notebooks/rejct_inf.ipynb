# %%
import sys
sys.path.append('../src')

import importlib
import dyn_accept_loop as dal
importlib.reload(dal)
import reject_inference as rinf
importlib.reload(rinf)
import helper as h
importlib.reload(h)

import matplotlib.pyplot as plt

from sklearn.linear_model import LogisticRegression

import lightgbm as lgbm

# %%
n_years = 20

model = lgbm.LGBMClassifier(random_state=1234) # DecisionTreeClassifier(min_samples_leaf=40) LogisticRegression(max_iter=400)

# %%
sim = dal.Simulate_acceptance_loop("gmsc.csv", model, 0.1, 0.1, n_years, enc_features=False, rej_inf=None)#rinf.EMsemisupervised)
results_generator = sim.run()

metrics = None
for iteration in results_generator:
    print(f'Itteration: {iteration[0]}) Accepted: {iteration[1].count(True)} | Denied: {iteration[1].count(False)} - New train set size: {iteration[2]}')
    metrics = iteration[3]

last_n_years = 5
bias = h.measure_bias(metrics_no["oracle"]["holdout"]['roc_auc'], metrics_no["model"]["holdout"]['roc_auc'], last_n_years)
    
x = range(1, n_years + 1)
plt.plot(x, metrics["oracle"]["holdout"]['roc_auc'], label = 'roc_auc-oracle')
plt.plot(x, metrics["model"]["holdout"]['roc_auc'], label = 'roc_auc-model')
#plt.plot(x, results["holdout"]['precision'], label = 'precision')
#plt.plot(x, results["holdout"]['f1'], label = 'f1')
#plt.plot(x, results["holdout"]['accuracy'], label = 'accuracy')
plt.text(0.75, 0.52, f'Avg. performance lost in last {last_n_years} iterations: {round(bias, 5)}')
plt.legend()
plt.ylim([0.5, 1.0])
plt.show()


print(f'Sampling Bias: {round(bias, 5)}')
# Out:
# Itteration: 0) Accepted: 1822 | Denied: 4253 - New train set size: (16822, 68)
# Itteration: 1) Accepted: 1822 | Denied: 4253 - New train set size: (18644, 68)
# Itteration: 2) Accepted: 1822 | Denied: 4253 - New train set size: (20466, 68)
# Itteration: 3) Accepted: 1822 | Denied: 4253 - New train set size: (22288, 68)
# Itteration: 4) Accepted: 1822 | Denied: 4253 - New train set size: (24110, 68)
# Itteration: 5) Accepted: 1822 | Denied: 4253 - New train set size: (25932, 68)
# Itteration: 6) Accepted: 1822 | Denied: 4253 - New train set size: (27754, 68)
# Itteration: 7) Accepted: 1822 | Denied: 4253 - New train set size: (29576, 68)
# Itteration: 8) Accepted: 1822 | Denied: 4253 - New train set size: (31398, 68)
# Itteration: 9) Accepted: 1822 | Denied: 4253 - New train set size: (33220, 68)
# Itteration: 10) Accepted: 1822 | Denied: 4253 - New train set size: (35042, 68)
# Itteration: 11) Accepted: 1822 | Denied: 4253 - New train set size: (36864, 68)
# Itteration: 12) Accepted: 1822 | Denied: 4253 - New train set size: (38686, 68)
# Itteration: 13) Accepted: 1822 | Denied: 4253 - New train set size: (40508, 68)
# Itteration: 14) Accepted: 1822 | Denied: 4253 - New train set size: (42330, 68)
# Itteration: 15) Accepted: 1822 | Denied: 4253 - New train set size: (44152, 68)
# Itteration: 16) Accepted: 1822 | Denied: 4253 - New train set size: (45974, 68)
# Itteration: 17) Accepted: 1822 | Denied: 4253 - New train set size: (47796, 68)
# Itteration: 18) Accepted: 1822 | Denied: 4253 - New train set size: (49618, 68)
# Itteration: 19) Accepted: 1822 | Denied: 4253 - New train set size: (51440, 68)
# Sampling Bias: 0.03112

# %%
sim = dal.Simulate_acceptance_loop("gmsc.csv", model, 0.1, 0.1, n_years, enc_features=False, rej_inf=rinf.augmentation())#rinf.EMsemisupervised)
results_generator = sim.run()

metrics_augm = None
for iteration in results_generator:
    #print(f'Itteration: {iteration[0]}) Accepted: {iteration[1].count(True)} | Denied: {iteration[1].count(False)} - New train set size: {iteration[2]}')
    metrics_augm = iteration[3]

bias_augm = h.measure_bias(metrics_augm["oracle"]["holdout"]['roc_auc'], metrics_augm["model"]["holdout"]['roc_auc'], last_n_years)
# Out:
# Itteration: 0) Accepted: 1822 | Denied: 4253 - New train set size: (16822, 68)
# Itteration: 1) Accepted: 1822 | Denied: 4253 - New train set size: (18644, 68)
# Itteration: 2) Accepted: 1822 | Denied: 4253 - New train set size: (20466, 68)
# Itteration: 3) Accepted: 1822 | Denied: 4253 - New train set size: (22288, 68)
# Itteration: 4) Accepted: 1822 | Denied: 4253 - New train set size: (24110, 68)
# Itteration: 5) Accepted: 1822 | Denied: 4253 - New train set size: (25932, 68)
# Itteration: 6) Accepted: 1822 | Denied: 4253 - New train set size: (27754, 68)
# Itteration: 7) Accepted: 1822 | Denied: 4253 - New train set size: (29576, 68)
# Itteration: 8) Accepted: 1822 | Denied: 4253 - New train set size: (31398, 68)
# Itteration: 9) Accepted: 1822 | Denied: 4253 - New train set size: (33220, 68)
# Itteration: 10) Accepted: 1822 | Denied: 4253 - New train set size: (35042, 68)
# Itteration: 11) Accepted: 1822 | Denied: 4253 - New train set size: (36864, 68)
# Itteration: 12) Accepted: 1822 | Denied: 4253 - New train set size: (38686, 68)
# Itteration: 13) Accepted: 1822 | Denied: 4253 - New train set size: (40508, 68)
# Itteration: 14) Accepted: 1822 | Denied: 4253 - New train set size: (42330, 68)
# Itteration: 15) Accepted: 1822 | Denied: 4253 - New train set size: (44152, 68)
# Itteration: 16) Accepted: 1822 | Denied: 4253 - New train set size: (45974, 68)
# Itteration: 17) Accepted: 1822 | Denied: 4253 - New train set size: (47796, 68)
# Itteration: 18) Accepted: 1822 | Denied: 4253 - New train set size: (49618, 68)
# Itteration: 19) Accepted: 1822 | Denied: 4253 - New train set size: (51440, 68)

# %%
plt.plot(x, metrics["oracle"]["holdout"]['roc_auc'], label = 'roc_auc-oracle')
plt.plot(x, metrics["model"]["holdout"]['roc_auc'], label = 'roc_auc-model')
plt.plot(x, metrics_augm["model"]["holdout"]['roc_auc'], label = 'roc_auc-model w augmentation')
plt.text(0.75, 0.52, f'Avg. performance lost in last {last_n_years} iterations: {round(bias_augm, 5)}')
plt.legend()
plt.ylim([0.5, 1.0])
plt.show()

print(f'Sampling Bias: {round(bias_augm, 5)}')
print(f'reduction in Sampling Bias: {round((bias - bias_augm)/bias,2)*100}%')
# Out:
# Sampling Bias: 0.02578
# reduction in Sampling Bias: 17.0%

# %%
sim = dal.Simulate_acceptance_loop("gmsc.csv", model, 0.1, 0.1, n_years, enc_features=False, rej_inf=rinf.augmentation(iterative=True))#rinf.EMsemisupervised)
results_generator = sim.run()

metrics_iter = None
for iteration in results_generator:
    print(f'Itteration: {iteration[0]}) Accepted: {iteration[1].count(True)} | Denied: {iteration[1].count(False)} - New train set size: {iteration[2]}')
    metrics_iter = iteration[3]

last_n_years = 5
bias_it_augm = h.measure_bias(metrics_iter["oracle"]["holdout"]['roc_auc'], metrics_iter["model"]["holdout"]['roc_auc'], last_n_years)
# Out:
# ---------------------------------------------------------------------------
# LightGBMError                             Traceback (most recent call last)
# C:\Users\HAASE~1.PAP\AppData\Local\Temp/ipykernel_9864/604909151.py in <module>
#       3
#       4 metrics_iter = None
# ----> 5 for iteration in results_generator:
#       6     print(f'Itteration: {iteration[0]}) Accepted: {iteration[1].count(True)} | Denied: {iteration[1].count(False)} - New train set size: {iteration[2]}')
#       7     metrics_iter = iteration[3]
#
# c:\Users\haase.PAPMEIER\InfSys\reject-infer-autoencoder\notebooks\../src\dyn_accept_loop.py in run(self, accpet_fraction)
#     170                 self.model.fit(all_train_X_trans, self.all_train_y)
#     171             else:
# --> 172                 self.rej_inf.fit(self.model,all_train_X_trans, self.all_train_y)
#     173
#     174             self.oracle.fit(oracle_all_train_X_trans, self.oracle_all_train_y)
#
# c:\Users\haase.PAPMEIER\InfSys\reject-infer-autoencoder\notebooks\../src\reject_inference.py in fit(self, model, x, y)
#      16             while(improv > 0.0001 and i < 1000):
#      17                 weights = np.divide(1,prev_pred,out=np.ones_like(prev_pred)/0.000001,where=prev_pred!=0)
# ---> 18                 model.fit(x, y, weights)
#      19                 pred = model.predict_proba(x)[:,0]
#      20                 improv = sum((prev_pred - pred)**2)
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\lightgbm\sklearn.py in fit(self, X, y, sample_weight, init_score, eval_set, eval_names, eval_sample_weight, eval_class_weight, eval_init_score, eval_metric, early_stopping_rounds, verbose, feature_name, categorical_feature, callbacks, init_model)
#     965                     valid_sets[i] = (valid_x, self._le.transform(valid_y))
#     966
# --> 967         super().fit(X, _y, sample_weight=sample_weight, init_score=init_score, eval_set=valid_sets,
#     968                     eval_names=eval_names, eval_sample_weight=eval_sample_weight,
#     969                     eval_class_weight=eval_class_weight, eval_init_score=eval_init_score,
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\lightgbm\sklearn.py in fit(self, X, y, sample_weight, init_score, group, eval_set, eval_names, eval_sample_weight, eval_class_weight, eval_init_score, eval_group, eval_metric, early_stopping_rounds, verbose, feature_name, categorical_feature, callbacks, init_model)
#     746         callbacks.append(record_evaluation(evals_result))
#     747
# --> 748         self._Booster = train(
#     749             params=params,
#     750             train_set=train_set,
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\lightgbm\engine.py in train(params, train_set, num_boost_round, valid_sets, valid_names, fobj, feval, init_model, feature_name, categorical_feature, early_stopping_rounds, evals_result, verbose_eval, learning_rates, keep_training_booster, callbacks)
#     290                                     evaluation_result_list=None))
#     291
# --> 292         booster.update(fobj=fobj)
#     293
#     294         evaluation_result_list = []
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\lightgbm\basic.py in update(self, train_set, fobj)
#    3019             if self.__set_objective_to_none:
#    3020                 raise LightGBMError('Cannot update due to null objective function.')
# -> 3021             _safe_call(_LIB.LGBM_BoosterUpdateOneIter(
#    3022                 self.handle,
#    3023                 ctypes.byref(is_finished)))
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\lightgbm\basic.py in _safe_call(ret)
#     123     """
#     124     if ret != 0:
# --> 125         raise LightGBMError(_LIB.LGBM_GetLastError().decode('utf-8'))
#     126
#     127
#
# LightGBMError: Check failed: (best_split_info.right_count) > (0) at D:\a\1\s\python-package\compile\src\treelearner\serial_tree_learner.cpp, line 663 .

# %%
x = range(1, n_years + 1)
plt.plot(x, metrics_no["oracle"]["holdout"]['roc_auc'], label = 'roc_auc-oracle')
plt.plot(x, metrics_no["model"]["holdout"]['roc_auc'], label = 'roc_auc-model')
plt.plot(x, metrics_simp["model"]["holdout"]['roc_auc'], label = 'roc_auc-model simple augmentation')
plt.plot(x, metrics_iter["model"]["holdout"]['roc_auc'], label = 'roc_auc-model iterative augmentation')
#plt.plot(x, results["holdout"]['precision'], label = 'precision')
#plt.plot(x, results["holdout"]['f1'], label = 'f1')
#plt.plot(x, results["holdout"]['accuracy'], label = 'accuracy')
plt.text(0.75, 0.52, f'Avg. performance lost in last {last_n_years} iterations: {round(bias, 5)}')
plt.legend()
plt.ylim([0.8, 0.9])
plt.show()


print(f'Sampling Bias: {round(bias_it_augm, 5)}')
print(f'reduction in Sampling Bias: {round((bias - bias_it_augm)/bias,2)*100}%')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\HAASE~1.PAP\AppData\Local\Temp/ipykernel_9864/2556712585.py in <module>
#       2 plt.plot(x, metrics_no["oracle"]["holdout"]['roc_auc'], label = 'roc_auc-oracle')
#       3 plt.plot(x, metrics_no["model"]["holdout"]['roc_auc'], label = 'roc_auc-model')
# ----> 4 plt.plot(x, metrics_simp["model"]["holdout"]['roc_auc'], label = 'roc_auc-model simple augmentation')
#       5 plt.plot(x, metrics_iter["model"]["holdout"]['roc_auc'], label = 'roc_auc-model iterative augmentation')
#       6 #plt.plot(x, results["holdout"]['precision'], label = 'precision')
#
# TypeError: 'NoneType' object is not subscriptable
